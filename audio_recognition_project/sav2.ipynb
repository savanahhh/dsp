# %% [markdown]
# <a href="https://colab.research.google.com/github/savanahhh/dsp/blob/main/audio_recognition_project/sav2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from thinkdsp import read_wave

myVoice = read_wave('thevoiceECE1.wav')
spec = myVoice.make_spectrum()

spec.plot()
